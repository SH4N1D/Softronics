# %% [markdown]
# ### Assignment 4

# %% [markdown]
# #### Tuple

# %% [markdown]
# Create a tuple containing five integer values and print it. Print the second element of a tuple. Find how many times the number 3 appears in a tuple. Find the position of the first occurrence of 5 in a tuple. Join two tuples and display the result. Add a new value 10 to an existing tuple. Display the smallest element present in a tuple. Display the largest element present in a tuple. Find the total sum of all elements in a tuple. Find the total number of elements present in a tuple.

# %%
a=(1,2,3,4,5)

# %%
print(a[1])
# Out:
# 2

# %%
a.count(3)
# Out:
# 1

# %%
a.index(5)
# Out:
# 4

# %%
b=(6,7,8,9)

# %%
a+b
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
a=list(a)
a.append(10)
a=tuple(a)

# %%
a
# Out:
# (1, 2, 3, 4, 5, 10)

# %%
min(a),max(a),sum(a),len(a)
# Out:
# (1, 10, 25, 6)

# %% [markdown]
# ### Assignment 5

# %% [markdown]
# ### Set

# %% [markdown]
# Create a set containing duplicate values and print the output. What do you observe? Add a new element to a set and display the updated set. Remove an element from a set. Remove an element that is not present in a set without producing an error. Add multiple elements from another set to an existing set. Delete all elements from a set and print the result. Find the total number of elements present in a set. Find the largest element in a set. Find the smallest element in a set. Find the sum of all elements present in a set. Find the common elements between two sets. Combine two sets and display all unique elements. Check whether a particular element exists in a set.

# %%
a=set()
a={1,2,3,4,2,5}
print(a)
# Out:
# {1, 2, 3, 4, 5}

# %%
a.add(10)
print(a)
# Out:
# {1, 2, 3, 4, 5, 10}

# %%
print(a)
a.remove(4)
print(a)
# Out:
# {1, 2, 3, 4, 5, 10}
# {1, 2, 3, 5, 10}

# %%
print(a)
a.discard(11)
# Out:
# {1, 2, 3, 5, 10}

# %%
b={6,7,8,9}
a.update(b)
print(a)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
a.clear()
print(a)
# Out:
# set()

# %%
len(a),min(a),max(a),sum(a)
# Out:
# (9, 1, 9, 45)

# %%
print(f"set a = {a}, set b = {b}")
print(f"Combination of two Sets = {a.union(b)}, Common Elements ={a.intersection(b)}")
# Out:
# set a = {1, 2, 3, 4, 5, 6, 7, 8, 9}, set b = {8, 9, 6, 7}
# Combination of two Sets = {1, 2, 3, 4, 5, 6, 7, 8, 9}, Common Elements ={8, 9, 6, 7}

# %%
24 in a
# Out:
# False

# %% [markdown]
# ### Assignment 6

# %% [markdown]
# ### Dictionary

# %% [markdown]
# Create a dictionary to store a student's name and age. Display the dictionary. Print the value associated with "name" from the dictionary. Add a new key "city" with any city name. Change the age of the person from 25 to 26. Delete the "name" key from the dictionary. Print all the keys present in the dictionary. Print all the values present in the dictionary. Display all key-value pairs of the dictionary. Find the total number of elements present in the dictionary. Check whether "age" is present in the dictionary. Create two dictionaries and combine them into a single dictionary. Convert all the values of a dictionary into a list. Add a new element "country" to the list obtained from dictionary values.

# %%
a={
    "name":"Slkcn",
    "age":23
}
print(a)
# Out:
# {'name': 'Slkcn', 'age': 23}

# %%
a["name"]
# Out:
# 'Slkcn'

# %%
a['city']='alewnbv'
a
# Out:
# {'name': 'Slkcn', 'age': 23, 'city': 'alewnbv'}

# %%
a['age']=26
a
# Out:
# {'name': 'Slkcn', 'age': 26, 'city': 'alewnbv'}

# %%
del a['name']
a
# Out:
# {'age': 26, 'city': 'alewnbv'}

# %%
a.keys(),a.values(),a.items(),len(a)
# Out:
# (dict_keys(['age', 'city']),
#  dict_values([26, 'alewnbv']),
#  dict_items([('age', 26), ('city', 'alewnbv')]),
#  2)

# %%
'age' in a
# Out:
# True

# %%
b={
    'eag':23,
    'awfaf':56
}
a.update(b)
print(a)
# Out:
# {'name': 'Slkcn', 'age': 23, 'eag': 23, 'awfaf': 56}

# %%
c=list(a.values())
c
# Out:
# ['Slkcn', 23, 23, 56]

# %%
c.append('country')
c
# Out:
# ['Slkcn', 23, 23, 56, 'country']

# %%
import shutil
print(shutil.which("pandoc"))
# Out:
# C:\Users\shani\AppData\Local\Pandoc\pandoc.EXE
